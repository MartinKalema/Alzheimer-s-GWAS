# %%
# !pip install pandas_plink
# Out:
# ...
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 276.6 kB/s eta 0:00:00a 0:00:01
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 kB 605.5 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 993.5 kB/s eta 0:00:0000:01:010m
# ...

# %% [markdown]
# Data Description File

# %% [markdown]
# | Column Name       | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            | Data Type             | Expected Values      | Notes                                                   |
# |-------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------|----------------------|----------------------------------------------------------|
# | Sample Index      | Row index of sample                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    | integer               | nan                  | nan                                                     |
# | Sample ID         | Sample identifier: ADNI_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | string                | nan                  | nan                                                     |
# | GC Score          | The call score of this SNP for the sample. GenTrain call score, an estimated accuracy for the called genotypes based on the proximity of the sample’s data points to their expected positions in the cluster plot. This value is always 1 for intensity-only loci.                                                                                                                                                                                                                                                       | float                 | 0-1 or NaN           | NaN: not available or not applicable                    |
# | SNP Index         | The row index of the SNP                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | integer               | 1-620901             | nan                                                     |
# | SNP Name          | The name of the SNP                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     | string                | nan                  | nan                                                     |
# | Chromosome        | The chromosome on which the SNP resides. Value can be any integer from 1 to 24 (23 for X, 24 for Y), and additional integers for any chromosomes that are not specified or that belong to other species.                                                                                                                                                                                                                                                                                                                  | integer               | 1-24                 | nan                                                     |
# | Position          | The chromosomal position of the SNP (0-based).                                                                                                                                                                                                                                                                                                                                                                                                                                                                          | integer               | nan                  | nan                                                     |
# | Plus/Minus Strand | Indicates the orientation of the forward probe strand. Forward probe strand is defined as the top strand for a strand-specific assay and the plus strand for a non-strand-specific assay.                                                                                                                                                                                                                                                                                                                                 | string                | + or -               | nan                                                     |
# | SNP               | The sequence of the SNP.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | string                | nan                  | nan                                                     |
# | Reference Strand  | Indicates the orientation of the reference strand.                                                                                                                                                                                                                                                                                                                                                                                                                                                                     | string                | nan                  | nan                                                     |
# | Allele1 - Forward | The genotype call for allele 1 on the forward strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                    | string                | A,C,G,T              | nan                                                     |
# | Allele2 - Forward | The genotype call for allele 2 on the forward strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                    | string                | A,C,G,T              | nan                                                     |
# | Allele1 - Top     | The genotype call for allele 1 on the top strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                        | string                | A,C,G,T              | nan                                                     |
# | Allele2 - Top     | The genotype call for allele 2 on the top strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                        | string                | A,C,G,T              | nan                                                     |
# | Allele1 - AB      | The genotype call for allele 1 in the AB format. AB genotype format is specific to BeadStudio software. Allele1 is coded as 0, 1, or 2 to represent the AA, AB, or BB genotypes respectively.                                                                                                                                                                                                                                                                                                                            | integer               | 0,1,2                | nan                                                     |
# | Allele2 - AB      | The genotype call for allele 2 in the AB format. Allele2 is coded as 0, 1, or 2 to represent the AA, AB, or BB genotypes respectively.                                                                                                                                                                                                                                                                                                                                                                                  | integer               | 0,1,2                | nan                                                     |
# | Allele1 - Plus    | The genotype call for allele 1 on the plus strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                       | string                | A,C,G,T              | nan                                                     |
# | Allele2 - Plus    | The genotype call for allele 2 on the plus strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                       | string                | A,C,G,T              | nan                                                     |
# | Allele1 - Minus   | The genotype call for allele 1 on the minus strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                      | string                | A,C,G,T              | nan                                                     |
# | Allele2 - Minus   | The genotype call for allele 2 on the minus strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                      | string                | A,C,G,T              | nan                                                     |
# | Allele1 - Design  | The genotype call for allele 1 on the design strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                     | string                | A,C,G,T              | nan                                                     |
# | Allele2 - Design  | The genotype call for allele 2 on the design strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                     | string                | A,C,G,T              | nan                                                     |
# | Allele1 - ILMN    | The genotype call for allele 1 on the ILMN strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                       | string                | A,C,G,T              | nan                                                     |
# | Allele2 - ILMN    | The genotype call for allele 2 on the ILMN strand (A, C, G, or T).                                                                                                                                                                                                                                                                                                                                                                                                                                                       | string                | A,C,G,T              | nan                                                     |
# | X Raw             | The raw intensity of the A allele.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | integer               | nan                  | nan                                                     |
# | Y Raw             | The raw intensity of the B allele.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | integer               | nan                  | nan                                                     |
# | B Allele Freq     | The B allele theta value of this SNP for the sample, relative to the cluster positions. This value is normalized so that it is zero if theta is less than or equal to the AA cluster's theta mean, 0.5 if it is equal to the AB cluster's theta mean, or 1 if it is equal to or greater than the BB cluster's theta mean. B Allele Freq is linearly interpolated between 0 and 1, or set to NaN for loci categorized as “intensity only.”                                                                                | float                 | 0-1 or NaN           | NaN: not available or not applicable                    |
# | Log R Ratio       | For loci included in BeadStudio statistics: the base-2 log of the normalized R value over the expected R value for the theta value (interpolated from the R-values of the clusters). For loci categorized as “intensity only”: adjusted so that the expected R value is based upon the weighted mean of the cluster itself.                                                                                                                                                                                             | float                 |                      | NaN: not available or not applicable                    |
